# %%
# %load cut_area_by_point.py


# In[23]:


# %load test.py


# In[ ]:


from __future__ import print_function
import traceback
import sys
import glob
 
from eccodes import *
 
INPUT = '/home/dp/data/ECMF_DAM/PUB/W_NAFP_C_ECMF_20171108054547_P_C1D11080000110800001'
STATIONINPUT='/home/dp/data/stationTest.txt'
VERBOSE = 1  # verbose error reporting
missingValue = 1e+20  # A value out of range 
eles=['10U','10V','2D','2T','CP','FAL','LCC','LSP','MSL','PWC','SD','SKT','TP','TCC','D','GH','Q','R','T','U','V','W']
                
 
def example():
    f = open(INPUT)
    
    for line in open(STATIONINPUT):
        lineSplit=line.split(" ")
        dateTime=lineSplit[0][4:]+lineSplit[1]+lineSplit[2]
        dateTime_2=dateTime+dateTime+"1"
        fileNameMatch=r"/home/dp/data/ECMF_DAM/PUB/W_NAFP_C_ECMF_*"+dateTime_2
        list=glob.glob(fileNameMatch)
        
        
        print(list)#文件名列表
    
    
        for onefile in list:
            f=open(onefile)
            message_count=codes_count_in_file(f) #文件中共有多少message
            print("message count %d" % (message_count))
            
            #跳过的部分
            while 1:
                gid = codes_grib_new_from_file(f)
                keyval = codes_get_string(gid, "shortName")
                #不在目录内则跳过
                if keyval.upper() not in eles:
                    continue
                
                print("%s = %s" % ("keyname", keyval))
                keyval = codes_get_string(gid, "level")
                print("%s = %s" % ("level", keyval))
                print("-" * 100)
                codes_release(gid)  
                
            
            f.close()
    
    
 
 
 
def main():
    try:
        example()
    except CodesInternalError as err:
        if VERBOSE:
            traceback.print_exc(file=sys.stderr)
        else:
            sys.stderr.write(err.msg + '\n')
 
        return 1
 
 
if __name__ == "__main__":
    sys.exit(main())
# Out:
# ['/home/dp/data/ECMF_DAM/PUB/W_NAFP_C_ECMF_20171108054547_P_C1D11080000110800001']
# message count 601
# keyname = q
# level = 250
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 850
# ----------------------------------------------------------------------------------------------------
# keyname = skt
# level = 0
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 20
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 800
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 800
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 50
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 50
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 20
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 800
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 70
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 70
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 850
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 900
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 900
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 20
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 150
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 600
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 925
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 600
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 600
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 950
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 600
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 200
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 1000
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 200
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 200
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 250
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 250
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 10
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 200
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 10
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 700
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 10
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 200
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 200
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 200
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 20
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 800
# ----------------------------------------------------------------------------------------------------
# keyname = 10v
# level = 0
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 20
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 20
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 800
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 10
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 850
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 400
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 20
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 700
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 700
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 70
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 600
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 50
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 950
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 950
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 900
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 900
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 850
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 50
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 50
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 250
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 1000
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 150
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 850
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 1000
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 150
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 150
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 400
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 400
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 250
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 950
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 100
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 700
# ----------------------------------------------------------------------------------------------------
# keyname = tcc
# level = 0
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 700
# ----------------------------------------------------------------------------------------------------
# keyname = lcc
# level = 0
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 900
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 300
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 700
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 925
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 100
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 150
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 300
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 700
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 700
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 400
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 70
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 925
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 50
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 600
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 600
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 100
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 925
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 100
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 100
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 70
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 500
# ----------------------------------------------------------------------------------------------------
# keyname = 10u
# level = 0
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 600
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 950
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 250
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 1000
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 1000
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 10
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 500
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 500
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 70
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 800
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 800
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 900
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 100
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 950
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 50
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 400
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 500
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 850
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 70
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 100
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 500
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 50
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 900
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 100
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 1000
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 250
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 1000
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 500
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 150
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 10
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 800
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 400
# ----------------------------------------------------------------------------------------------------
# keyname = sd
# level = 0
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 900
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 300
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 300
# ----------------------------------------------------------------------------------------------------
# keyname = 2d
# level = 0
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 70
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 950
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 300
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 300
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 300
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 925
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 1000
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 400
# ----------------------------------------------------------------------------------------------------
# keyname = 2t
# level = 0
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 20
# ----------------------------------------------------------------------------------------------------
# keyname = w
# level = 400
# ----------------------------------------------------------------------------------------------------
# keyname = msl
# level = 0
# ----------------------------------------------------------------------------------------------------
# keyname = r
# level = 200
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 250
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 925
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 850
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 850
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 500
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 10
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 10
# ----------------------------------------------------------------------------------------------------
# keyname = q
# level = 950
# ----------------------------------------------------------------------------------------------------
# keyname = t
# level = 300
# ----------------------------------------------------------------------------------------------------
# keyname = gh
# level = 150
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 150
# ----------------------------------------------------------------------------------------------------
# keyname = d
# level = 500
# ----------------------------------------------------------------------------------------------------
# keyname = v
# level = 925
# ----------------------------------------------------------------------------------------------------
# keyname = u
# level = 925
# ----------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-bcd70c73747d> in <module>()
#      78
#      79 if __name__ == "__main__":
# ---> 80     sys.exit(main())
#      81
#      82
#
# <ipython-input-5-bcd70c73747d> in main()
#      67 def main():
#      68     try:
# ---> 69         example()
#      70     except CodesInternalError as err:
#      71         if VERBOSE:
#
# <ipython-input-5-bcd70c73747d> in example()
#      47             while 1:
#      48                 gid = codes_grib_new_from_file(f)
# ---> 49                 keyval = codes_get_string(gid, "shortName")
#      50                 #不在目录内则跳过
#      51                 if keyval.upper() not in eles:
#
# /home/dp/anaconda3/envs/ecwmf/lib/python2.7/site-packages/gribapi/gribapi.pyc in modified(*args, **kw)
#      85                     allowed_types = (allowed_types,)
#      86                 assert any([isinstance(param, type1) for type1 in allowed_types]), \
# ---> 87                     "Parameter '%s' should be of type %s" % (name, " or ".join([t.__name__ for t in allowed_types]))
#      88             return _func_(**kw)
#      89         return modified
#
# AssertionError: Parameter 'msgid' should be of type int
